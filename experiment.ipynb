# %%
import sys
import os
import pandas as pd
from Workflow.google_storage_workflow import create_folder_if_not_exists, upload_csv_to_bucket, read_csv_from_gcs
from Models.gemini_model import GeminiModel
import pandas as pd
from concurrent.futures import ProcessPoolExecutor
from typing import Any, List, Tuple, Dict 
from pydantic import BaseModel, Field
import numpy as np
from pydantic import BaseModel
from Models.gpt_model import GPTModel
from Models.gemini_model import GeminiModel
from typing import List, Dict, Tuple, Any
from concurrent.futures import ThreadPoolExecutor
from pathlib import Path
from typing import Union
from typing import Union
from bs4 import BeautifulSoup
from typing import Union
import pandas as pd
from google.cloud import storage
from urllib.parse import urlparse

# %%
def llm_imputer(df:pd.DataFrame, idx:int) -> Dict[str, Any]:
    """ 
    Execute LLM imputation task for a given SKU and return the output in a DataFrame

    Args:
        df: pd.DataFrame, PMA dataframe
        idx: int, index of the SKU to be processed
    Returns:
        dict: output in a dictionary format
    """

    input_df = df.copy()

    class SubAttribution(BaseModel):

        Has_Coffee_Service: str = Field(
            description="True, False, or undetermined. Indicates if the business has coffee makers or not as indicated in the scraped text"
        )
        Has_Coffee_Service_Explanation: str = Field(
            description="Brief CoT explanation of the reasoning behind the coffee service classification."
        )
        Has_Vending_Machine_Service: str = Field(
            description="True, False, or undetermined. Indicates if the business has vending machines or not as indicated in the scraped text"
        )
        Has_Vending_Machine_Service_Explanation: str = Field(
            description="Brief CoT explanation of the reasoning behind the vending machine service classification."
        )
        Has_Micro_Market_Service: str = Field(
            description="True, False, or undetermined. Indicates if the business has an in-house micro market or not as indicated in the scraped text"
        )
        Has_Micro_Market_Service_Explanation: str = Field(
            description="Brief CoT explanation of the reasoning behind the micro market service classification."
        )

        Decision_Maker_Name: str = Field(
            description="Full name of the decision maker for operations/procurement/office management."
        )
        Decision_Maker_Title: str = Field(
            description="Job title of the decision maker for operations/procurement/office management."
        )
        Decision_Maker_Phone: str = Field(
            description="Phone number of the decision maker for operations/procurement/office management."
        )
        Decision_Maker_Email_Address: str = Field(
            description="Email address of the decision maker for operations/procurement/office management."
        )
        Business_Name: str = Field(
            description="Name of the business."
        )
        Business_Location: str = Field(
            description="Location of the business (Full address if available)."
        )
        Business_Summary: str = Field(
            description="A brief summary of the business, including its name, location, and any relevant details."
        )
        Canteen_Value_Proposition: str = Field(
            description="A value proposition that Canteen can communicate tailored to this specific businesses' needs around coffee, micro-markets, vending machines."
        )

    # Initialize LLM 
    model = GeminiModel()

    # Generate system instruction
    sys_inst = f'''
    You are an expert business leads parser.

    ### Task
    Using a chain-of-thought style reasoning, your task is to analyze the scraped text and determine if the business has coffee makers, vending machines, or an in-house micro market.
    You will also identify the decision maker for operations/procurement/office management, including their full name, job title, phone number, and email address.

    ### Input Format
    You will be provided with scraped text from a business website. 
    The text may contain various terms and phrases that could indicate the presence of coffee makers, vending machines, or an in-house micro market. 
    You will also look for the decision maker's information, including their full name, job title, phone number, and email address.

    ### Output Format
    Provide your evaluation as a JSON object in the following structure:
    {{
        Has_Coffee_Service: str = Field(
            description="True, False, or undetermined. Indicates if the business has coffee makers or not as indicated in the scraped text"
        )
        Has_Coffee_Service_Explanation: str = Field(
            description="Brief CoT explanation of the reasoning behind the coffee service classification."
        )
        Has_Vending_Machine_Service: str = Field(
            description="True, False, or undetermined. Indicates if the business has vending machines or not as indicated in the scraped text"
        )
        Has_Vending_Machine_Service_Explanation: str = Field(
            description="Brief CoT explanation of the reasoning behind the vending machine service classification."
        )
        Has_Micro_Market_Service: str = Field(
            description="True, False, or undetermined. Indicates if the business has an in-house micro market or not as indicated in the scraped text"
        )
        Has_Micro_Market_Service_Explanation: str = Field(
            description="Brief CoT explanation of the reasoning behind the micro market service classification."
        )
        Decision_Maker_Name: str = Field(
            description="Full name of the decision maker for operations/procurement/office management. undetermined if none exists"
        )
        Decision_Maker_Title: str = Field(
            description="Job title of the decision maker for operations/procurement/office management. undetermined if none exists"
        )
        Decision_Maker_Phone: str = Field(
            description="Phone number of the decision maker for operations/procurement/office management. undetermined if none exists"
        )
        Decision_Maker_Email_Address: str = Field(
            description="Email address of the decision maker for operations/procurement/office management. undetermined if none exists"
        )
        Business_Summary: str = Field(
            description="A brief summary of the business, including its name, location, and any relevant details."
        )
        Canteen_Value_Proposition: str = Field(
            description="A value proposition that Canteen can communicate tailored to this specific businesses' needs around coffee, micro-markets, vending machines."
        )
    }}

    ### Constraints
    - The output must be a valid JSON object.
    - Do not include any additional text or explanations outside of the JSON object.
    - Ensure that the JSON object is well-structured and easy to read.


    '''

    # Generate user instruction
    user_inst = f''' 
       {input_df.loc[idx,'html_content_cleaned']} 
    '''

    # Generate response by leveraging LLM inference
    output = dict(model.generate_response(sys_inst, user_inst, SubAttribution, response_format_flag=True))
    print(output)
    total_prompt_io = sys_inst + user_inst + str(output)

    # Store the output in the inference dataframe
    for key, value in output.items():
        input_df.loc[idx, key] = value

    minimal_df = input_df.loc[[idx]]

    return minimal_df.to_dict(orient='records')[0]



def process_row(args: Tuple[pd.DataFrame, int, str]) -> Any:
    """
    Process a single row for subattribution.

    Args:
        args (Tuple[pd.DataFrame, int, str]): A tuple containing the DataFrame,
            the row index, and the source_type.
    
    Returns:
        Any: The result of the subattributor function.
    """
    inference_df, idx = args
    return llm_imputer(inference_df, idx)


def parallel_llm_evals(
    inference_df: pd.DataFrame
) -> pd.DataFrame:
    """
    Apply the `llm_evaluator` function to each row of a DataFrame in parallel.

    This function parallelizes the process of generating subattributions for each
    row in the input DataFrame using multiple CPU cores.

    Args:
        inference_df (pd.DataFrame): The input DataFrame for which subattributions will be computed.
        source_type (str): The source type argument passed to the `subattributor` function.

    Returns:
        pd.DataFrame: A DataFrame containing the list of subattributions.
    """
    args_list: List[Tuple[pd.DataFrame, int, str]] = [
        (inference_df, idx) for idx, _ in inference_df.iterrows()
    ]
    
    with ProcessPoolExecutor() as executor:
        inner_list: List[Any] = list(
            executor.map(process_row, args_list)
        )

    return pd.DataFrame(inner_list)

# %%
def extract_text_from_html(html: Union[str, bytes]) -> str:
    """
    Strip out all HTML tags, scripts, styles, and metadata from an HTML document
    and return the visible text content.

    Parameters
    ----------
    html : str or bytes
        The raw HTML to clean.

    Returns
    -------
    str
        The concatenated, whitespace-normalized text extracted from the HTML.
    """
    # Parse the document
    soup = BeautifulSoup(html, "html.parser")

    # Remove elements that shouldn’t contribute to visible text
    for tag in soup(["script", "style", "head", "meta", "link", "noscript"]):
        tag.extract()

    # Get raw text and normalize whitespace
    text = soup.get_text(separator="\n")

    # Break into lines, strip each, and re-join non-blank lines
    lines = (line.strip() for line in text.splitlines())
    chunks = (chunk for line in lines for chunk in line.split("  ") if chunk)
    cleaned = "\n".join(chunk for chunk in chunks if chunk)

    return cleaned

# %%
def html_folder_to_dataframe(
    folder_path: Union[str, Path]
) -> pd.DataFrame:
    """
    Traverse a local folder recursively, locate all .html files,
    and assemble a pandas DataFrame with file names and raw HTML content.

    Parameters
    ----------
    folder_path : Union[str, pathlib.Path]
        Path to the root folder to traverse.

    Returns
    -------
    pd.DataFrame
        DataFrame with columns:
        - 'file_name': the name of the HTML file
        - 'html_content': the full text content of the HTML file

    Raises
    ------
    ValueError
        If `folder_path` does not exist or is not a directory.
    """
    folder = Path(folder_path)
    if not folder.exists() or not folder.is_dir():
        raise ValueError(f"Invalid folder path: {folder_path}")

    records = []
    # Traverse recursively for .html files
    for file in folder.rglob("*.html"):
        try:
            content = file.read_text(encoding="utf-8", errors="ignore")
        except Exception as e:
            # Skip files that can't be read
            continue
        records.append({
            "file_name": file.name,
            "html_content": content,
        })

    return pd.DataFrame(records)

# %%
def download_html_files_to_dataframe(
    bucket_name: str,
    prefix: str,
    client: storage.Client | None = None,
    metadata_parent: str = None,
    metadata_child: str = None
) -> pd.DataFrame:
    """
    Download all .html files under a given Google Cloud Storage prefix and
    return them in a DataFrame.

    Parameters
    ----------
    bucket_name : str
        Name of the GCS bucket (e.g., "my-bucket").
    prefix : str
        Folder path prefix within the bucket (e.g., "folder/subfolder").
    client : storage.Client | None, optional
        An existing Google Cloud Storage client. If None, a new client is created.
    metadata_parent : str, optional
        Metadata key for filtering parent files.
    metadata_child : str, optional
        Metadata key for filtering child files.
        
    Returns
    -------
    pd.DataFrame
        DataFrame with columns:
        - file_name: base name of each HTML file
        - html_content: the text content of the HTML file

    Raises
    ------
    ValueError
        If the bucket does not exist or no HTML files are found.
    """
    # Initialize client
    storage_client = client or storage.Client()
    bucket = storage_client.bucket(bucket_name)
    if not bucket.exists():
        raise ValueError(f"Bucket '{bucket_name}' does not exist.")

    records = []
    # List all blobs under the prefix
    blobs = storage_client.list_blobs(bucket_name, prefix=prefix)
    for blob in blobs:
        if not blob.name.lower().endswith(".html"):
            continue
        if blob.metadata.get("Parent") != metadata_parent and metadata_parent is not None:
            continue
        if blob.metadata.get("Child") != metadata_child and metadata_child is not None:
            continue
        try:
            content = blob.download_as_text(encoding="utf-8")
        except Exception as e:
            # Skip unreadable files
            continue
        file_name = blob.name.rsplit("/", 1)[-1]
        records.append({
            "file_name": file_name,
            "url": blob.metadata.get("url",""),
            "Parent Account": blob.metadata.get("Parent",""),
            "Child": blob.metadata.get("Child",""),
            "html_content": content,
        })

    if not records:
        raise ValueError(f"No HTML files found under '{prefix}' in bucket '{bucket_name}'.")

    return pd.DataFrame(records)

# %%
def aggregator(sitemap_df:pd.DataFrame, df:pd.DataFrame, idx:int) -> dict:
    """ 
    Execute LLM aggregator task for a given SKU and return the output in a DataFrame

    Args:
        df: pd.DataFrame, PMA dataframe
        idx: int, index of the SKU to be processed
    Returns:
        pd.DataFrame: output in a dataframe format
    """

    input_df = df.copy()
    sitemap_df = sitemap_df.copy()

    class SubAttribution(BaseModel):

        Has_Coffee_Service: str = Field(
            description="True, False, or undetermined. Indicates if the business has coffee makers or not as indicated in the scraped text"
        )
        Has_Coffee_Service_Explanation: str = Field(
            description="Brief CoT explanation of the reasoning behind the coffee service classification."
        )
        Has_Vending_Machine_Service: str = Field(
            description="True, False, or undetermined. Indicates if the business has vending machines or not as indicated in the scraped text"
        )
        Has_Vending_Machine_Service_Explanation: str = Field(
            description="Brief CoT explanation of the reasoning behind the vending machine service classification."
        )
        Has_Micro_Market_Service: str = Field(
            description="True, False, or undetermined. Indicates if the business has an in-house micro market or not as indicated in the scraped text"
        )
        Has_Micro_Market_Service_Explanation: str = Field(
            description="Brief CoT explanation of the reasoning behind the micro market service classification."
        )

        Decision_Maker_Name: str = Field(
            description="Full name of the decision maker for operations/procurement/office management."
        )
        Decision_Maker_Title: str = Field(
            description="Job title of the decision maker for operations/procurement/office management."
        )
        Decision_Maker_Phone: str = Field(
            description="Phone number of the decision maker for operations/procurement/office management."
        )
        Decision_Maker_Email_Address: str = Field(
            description="Email address of the decision maker for operations/procurement/office management."
        )
        Business_Name: str = Field(
            description="Name of the business."
        )
        Business_Location: str = Field(
            description="Location of the business."
        )
        Business_Summary: str = Field(
            description="A brief summary of the business, including its name, location, and any relevant details."
        )
        Canteen_Value_Proposition: str = Field(
            description="A value proposition that Canteen can communicate tailored to this specific businesses' needs around coffee, micro-markets, vending machines."
        )

    # Initialize LLM 
    model = GeminiModel()

    # Generate system instruction
    sys_inst = f'''
    You are an expert business leads parser.

    ### Task
    Using a chain-of-thought style reasoning, your task is to analyze the scraped text and determine if the business has coffee makers, vending machines, or an in-house micro market.
    You will also identify the most relevant/populated decision makers for operations/procurement/office management, including their full name, job title, phone number, and email address.

    ### Input Format
    You will be provided with scraped and parsed texts from many business websites. 

    ### Output Format
    Provide your evaluation as a JSON object in the following structure:
    {{
        Has_Coffee_Service: str = Field(
            description="True, False, or undetermined. Indicates if the business has coffee makers or not as indicated in the scraped text"
        )
        Has_Coffee_Service_Explanation: str = Field(
            description="Brief CoT explanation of the reasoning behind the coffee service classification."
        )
        Has_Vending_Machine_Service: str = Field(
            description="True, False, or undetermined. Indicates if the business has vending machines or not as indicated in the scraped text"
        )
        Has_Vending_Machine_Service_Explanation: str = Field(
            description="Brief CoT explanation of the reasoning behind the vending machine service classification."
        )
        Has_Micro_Market_Service: str = Field(
            description="True, False, or undetermined. Indicates if the business has an in-house micro market or not as indicated in the scraped text"
        )
        Has_Micro_Market_Service_Explanation: str = Field(
            description="Brief CoT explanation of the reasoning behind the micro market service classification."
        )
        Decision_Maker_Name: str = Field(
            description="Full name of the decision maker for operations/procurement/office management. undetermined if none exists"
        )
        Decision_Maker_Title: str = Field(
            description="Job title of the decision maker for operations/procurement/office management. undetermined if none exists"
        )
        Decision_Maker_Phone: str = Field(
            description="Phone number of the decision maker for operations/procurement/office management. undetermined if none exists"
        )
        Decision_Maker_Email_Address: str = Field(
            description="Email address of the decision maker for operations/procurement/office management. undetermined if none exists"
        )
        Business_Summary: str = Field(
            description="A brief summary of the business, including its name, location, and any relevant details."
        )
        Canteen_Value_Proposition: str = Field(
            description="A value proposition that Canteen can communicate tailored to this specific businesses' needs around coffee, micro-markets, vending machines."
        )
    }}

    ### Constraints
    - The output must be a valid JSON object.
    - Do not include any additional text or explanations outside of the JSON object.
    - Ensure that the JSON object is well-structured and easy to read.
    '''
    input_df = input_df.drop(columns=['html_content_cleaned','html_content'],axis=1)
    # Generate user instruction
    user_inst = f''' 
       {input_df.to_string(index=False)} 
    '''

    # Generate response by leveraging LLM inference
    output = dict(model.generate_response(sys_inst, user_inst, SubAttribution, response_format_flag=True))
    print(output)
    total_prompt_io = sys_inst + user_inst + str(output)

    # Store the output in the inference dataframe
    for key, value in output.items():
        sitemap_df.loc[idx, key] = value

    minimal_df = sitemap_df.loc[[idx]]

    return sitemap_df

# %%
def list_html_metadata(gs_path: str) -> List[Dict[str, Any]]:
    """
    List metadata for all .html files under a GCS folder path.

    Args:
        gs_path (str): GCS URI in the form "gs://BUCKET_NAME/path/to/folder/"

    Returns:
        List[Dict[str, Any]]: A list of metadata dicts, one per HTML file, e.g.:
            {
              "name": "path/to/folder/page.html",
              "size": 12345,
              "content_type": "text/html",
              "updated": "2025-05-09T12:34:56.789012Z",
              "metadata": {"url": "...", ...}  # any user‐set metadata
            }
    """
    # parse the gs:// URI
    parsed = urlparse(gs_path)
    if parsed.scheme != "gs":
        raise ValueError(f"Invalid GCS path: {gs_path!r}, must start with gs://")

    bucket_name = parsed.netloc
    prefix = parsed.path.lstrip("/")

    client = storage.Client()
    bucket = client.bucket(bucket_name)

    results: List[Dict[str, Any]] = []
    # list all blobs under prefix (recursively)
    for blob in bucket.list_blobs(prefix=prefix):
        if blob.name.lower().endswith(".html"):
            results.append(blob.metadata)

    return results

# %%
def create_parent_child_df() -> pd.DataFrame:
    """
    Create a parent-child DataFrame from the HTML metadata in GCS.

    Returns:
        pd.DataFrame: A DataFrame with columns 'Parent-Child-ID', 'Parent', and 'Child'.
    """
    # List metadata for all HTML files in the GCS folder
    metadata_df = pd.DataFrame(list_html_metadata("gs://data-extraction-services/Canteen-Sales_Poc/results-round-2"))
    # Create hybrid ID for parent-child relationship
    metadata_df['Parent-Child-ID'] = metadata_df['Parent'] + "-" + metadata_df['Child']
    # Drop duplicates based on the hybrid ID
    parent_child_df = metadata_df.copy(deep=True)
    parent_child_df.drop_duplicates(
        subset=['Parent-Child-ID'],
        inplace=True
    )

    # 1b) Then narrow to just the three columns
    parent_child_df = parent_child_df[['Parent-Child-ID','Parent','Child']].reset_index(drop=True)
    parent_child_df.sort_values(by='Parent', inplace=True)
    parent_child_df = parent_child_df.reset_index(drop=True)
    # parent_child_df.to_csv("out.csv")
    return parent_child_df, metadata_df

# %%
sitemap_df = pd.read_csv("input/sitemap/sitemap_canteen_sales_leads.csv")
parent_child_df, metadata_df = create_parent_child_df()

# %%
def orchestrate_sitemap_parse(parent_child_df: pd.DataFrame) -> pd.DataFrame:
    """ 
        Orchestrate the parsing of a sitemap DataFrame and return the updated DataFrame.
        Args:
            sitemap_df: pd.DataFrame, DataFrame containing the sitemap data.
        Returns:    
            pd.DataFrame: Updated DataFrame with parsed data.
    """
    # Iterate over sites in the sitemap
    for idx, row in parent_child_df.iterrows():
        try:
            # Get the account name, address, and city from the sitemap
            parent = row['Parent']
            child = row['Child']
            print(f"Processing {parent} - {child}")
            # Download HTML files from GCS and convert to DataFrame
            df = download_html_files_to_dataframe(
                "data-extraction-services",
                f"Canteen-Sales_Poc/results-round-2",
                metadata_parent=parent,
                metadata_child=child
            )
            # Clean the HTML content
            df['html_content_cleaned'] = df['html_content'].apply(lambda x: extract_text_from_html(str(x)))

            # Perform LLM evaluation
            df = parallel_llm_evals(df)
            df.to_csv(f"intermediate-outputs/intermediate-{parent}-{child}.csv", index=False)

            # Aggregate the results via LLM and write back to the dataframe
            parent_child_df = aggregator(parent_child_df, df, idx)
        except Exception as e:
            print(f"Error processing {parent} - {child} - {e}")
            continue

    return parent_child_df

parent_child_df = orchestrate_sitemap_parse(parent_child_df)
# Out:
# Processing Aldelano Corp - Hickman Realty Group Inc.-Jack
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'There is no mention of coffee service in the scraped text, so it is undetermined.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'There is no mention of vending machine service in the scraped text, so it is undetermined.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'There is no mention of a micro market service in the scraped text, so it is undetermined.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Example Business', 'Business_Location': 'Example Location', 'Business_Summary': 'This is an example business located in an example location. More information is needed to provide a comprehensive summary.', 'Canteen_Value_Proposition': "Without information on the business's current setup or needs, a general value proposition would be to offer a comprehensive refreshment solution, including coffee, vending, and micro-market options, tailored to improve employee satisfaction and productivity."}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'There is no mention of coffee service in the scraped text.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'There is no mention of vending machine service in the scraped text.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'There is no mention of a micro market service in the scraped text.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Haltom Home Team', 'Business_Location': '50 Stonebridge Blvd, Jackson, TN 38305', 'Business_Summary': 'Haltom Home Team is a real estate agency located in Jackson, TN, specializing in selling homes in Jackson and surrounding areas. They are local REALTORS® serving the West Tennessee area.', 'Canteen_Value_Proposition': 'As a real estate office, Haltom Home Team could benefit from providing complimentary coffee and snacks to clients and staff. A coffee and vending machine service could enhance the office environment and improve client satisfaction, making the experience more comfortable and welcoming.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not contain any information about coffee service.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not contain any information about vending machine service.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not contain any information about micro market service.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Hickman Realty Group, INC', 'Business_Location': 'Jackson, TN', 'Business_Summary': 'Hickman Realty Group, INC is a real estate company specializing in West Tennessee real estate. They have offices in Jackson, Milan, and Humboldt.', 'Canteen_Value_Proposition': 'Since Hickman Realty Group has multiple offices throughout West Tennessee, Canteen can offer coffee, micro-market, and vending machine services to improve employee satisfaction and retention at each of their locations.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'There is no mention of coffee service in the scraped text. Therefore, it is undetermined whether the business has a coffee service.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'There is no mention of vending machines in the scraped text. Therefore, it is undetermined whether the business has vending machines.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'There is no mention of a micro market in the scraped text. Therefore, it is undetermined whether the business has a micro market.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Lilly Realty', 'Business_Location': '208 Cheyenne Dr, Suite B, Jackson, TN 38305', 'Business_Summary': 'Lilly Realty is a real estate company located in Jackson, TN. They assist clients with buying, selling, and renting properties.', 'Canteen_Value_Proposition': 'Since Lilly Realty is a real estate company, providing coffee, vending, and micro-market services could enhance the office environment for both employees and visiting clients, creating a more welcoming and productive atmosphere. Canteen can offer a customized solution to fit their specific needs and budget.'}
# Gemini call error on attempt 1: 503 502:Bad Gateway
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text provided does not contain any information about coffee service.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text provided does not contain any information about vending machine service.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text provided does not contain any information about micro market service.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'undetermined', 'Business_Location': 'undetermined', 'Business_Summary': 'The request could not be satisfied due to a CloudFront error, indicating a potential issue with the server configuration or high traffic. The specific business name and location are undetermined.', 'Canteen_Value_Proposition': "Without information about the business's current amenities or needs, a tailored value proposition is not possible. However, Canteen can generally offer solutions to improve employee satisfaction and productivity through coffee, micro-markets, and vending services."}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text only contains a security check message and does not provide any information about the business or its amenities like coffee service.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text only contains a security check message and does not provide any information about the business or its amenities like vending machines.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text only contains a security check message and does not provide any information about the business or its amenities like a micro market.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'landsearch.com', 'Business_Location': 'undetermined', 'Business_Summary': 'The scraped text is from landsearch.com and shows a security check. No business information is available.', 'Canteen_Value_Proposition': 'Due to the lack of information, a value proposition cannot be determined. Gather business details to tailor a specific offering.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'There is no mention of coffee service in the scraped text. Therefore, it is undetermined whether the business has a coffee service.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'There is no mention of vending machines in the scraped text. Therefore, it is undetermined whether the business has vending machines.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'There is no mention of a micro market in the scraped text. Therefore, it is undetermined whether the business has a micro market.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Jack Lingo, REALTOR®', 'Business_Location': '246 Rehoboth Avenue, Rehoboth Beach, DE, 19971\n1240 Kings Highway, Lewes, DE, 19958\n28442 Dupont Boulevard, Millsboro, DE, 19966', 'Business_Summary': 'Jack Lingo, REALTOR® is a family-owned and operated Delaware real estate business with offices in Rehoboth Beach, Lewes, and Millsboro. They focus on representing home buyers and sellers and offer residential and commercial real estate services, including sales and rentals.', 'Canteen_Value_Proposition': 'Canteen can offer Jack Lingo, REALTOR® a tailored refreshment program to enhance the experience for their agents and clients at each of their office locations. This could include coffee, vending, or micro-market solutions to provide convenient access to beverages and snacks, creating a more welcoming and productive environment.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'There is no mention of coffee service in the scraped text.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'There is no mention of vending machine service in the scraped text.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'There is no mention of a micro market service in the scraped text.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Example Business', 'Business_Location': '123 Main Street, Anytown, USA', 'Business_Summary': 'Example Business is located in Anytown, USA. More information is needed to provide a detailed summary.', 'Canteen_Value_Proposition': 'Canteen can provide a tailored solution for Example Business including coffee, micro-markets, and vending machines to improve employee satisfaction and productivity. A needs assessment would be the first step.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'There is no mention of coffee service in the scraped text.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'There is no mention of vending machine service in the scraped text.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'There is no mention of a micro market service in the scraped text.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Clear Choice Realty LLC', 'Business_Location': '451 TN Ave S Suite B, Parsons, TN 38363', 'Business_Summary': 'Clear Choice Realty LLC is a real estate company located in Parsons, TN. They offer services for buyers and sellers in various communities in the surrounding area.', 'Canteen_Value_Proposition': 'Since Clear Choice Realty caters to buyers and sellers of property, Canteen can offer coffee and snack options for the Clear Choice Realty office, as well as options to stage open houses with coffee and snack options, creating a more welcoming experience for potential buyers.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not mention coffee makers. Therefore, it is undetermined whether they have coffee service or not.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not mention vending machines. Therefore, it is undetermined whether they have vending machine service or not.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not mention micro markets. Therefore, it is undetermined whether they have micro market service or not.', 'Decision_Maker_Name': 'Michelle Lilly', 'Decision_Maker_Title': 'Realtor\nÂ®\nâ\x9f¯', 'Decision_Maker_Phone': '(731) 267-6945', 'Decision_Maker_Email_Address': 'michellelillyrealtor@gmail.com', 'Business_Name': 'Lilly Realty', 'Business_Location': '208 Cheyenne Dr, Suite B Jackson, TN 38305', 'Business_Summary': 'Lilly Realty is a real estate company located in Jackson, TN. They assist clients in buying, selling, and leasing properties in the Medina, TN area. Michelle Lilly is a Realtor with Lilly Realty.', 'Canteen_Value_Proposition': 'Canteen can offer Lilly Realty and its agents a coffee and snack program to enhance their office environment and provide a convenient amenity for both staff and visiting clients, potentially improving morale and productivity. A micro-market or vending solution could be pitched as a modern amenity that aligns with the growing nature of Medina.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not contain any information about coffee service.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not contain any information about vending machine service.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not contain any information about micro market service.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Lilly Realty', 'Business_Location': '208 Cheyenne Dr, Suite B Jackson, TN 38305', 'Business_Summary': 'Lilly Realty is a real estate company located in Jackson, TN. They provide services for buyers, sellers, and rentals.', 'Canteen_Value_Proposition': 'Canteen can offer Lilly Realty a coffee, micro-market, and vending machine solution to enhance the workplace environment for its employees and clients. This could increase employee satisfaction and provide a convenient amenity for visitors.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'There is no mention of coffee service in the scraped text.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'There is no mention of vending machine service in the scraped text.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'There is no mention of micro market service in the scraped text.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Haltom Home Team', 'Business_Location': '50 Stonebridge Blvd, Jackson, TN 38305', 'Business_Summary': 'Haltom Home Team is a real estate agency located in Jackson, TN, specializing in selling homes in Jackson and surrounding areas.', 'Canteen_Value_Proposition': 'As a real estate agency, Haltom Home Team could benefit from providing coffee and beverage options for clients and employees during meetings and office hours. Canteen can offer a tailored solution to enhance their office environment and client experience.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'There is no mention of coffee service in the scraped text.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'There is no mention of vending machine service in the scraped text.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'There is no mention of micro market service in the scraped text.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Example Business', 'Business_Location': 'Example Location', 'Business_Summary': 'This is an example business summary.', 'Canteen_Value_Proposition': 'Based on the limited information available, Canteen can offer a comprehensive refreshment solution including coffee, vending, and micro-market options to enhance employee satisfaction and productivity. A needs assessment would be required to understand specific requirements.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text is an online repository of economic research and papers. There is no information about the business having coffee services.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text is an online repository of economic research and papers. There is no information about the business having vending machine services.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text is an online repository of economic research and papers. There is no information about the business having micro market services.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Booth School of Business', 'Business_Location': 'Chicago, Illinois (United States)', 'Business_Summary': 'The text is about Jack Mountjoy, who is affiliated with the Booth School of Business at the University of Chicago. It includes his research publications, citations, and other relevant details.', 'Canteen_Value_Proposition': 'As an academic institution focused on research, providing convenient and high-quality food and beverage options can support the well-being and productivity of faculty, staff, and students. Canteen can offer customized coffee, vending, and micro-market solutions to meet the specific needs of the Booth School of Business.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not provide any information about the presence of coffee makers at the business.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not provide any information about the presence of vending machines at the business.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not provide any information about the presence of a micro market at the business.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'imodules', 'Business_Location': 'undetermined', 'Business_Summary': 'The scraped text indicates that the user is unable to access imodules.com due to a security block. The text does not provide much information about the business itself other than its domain name.', 'Canteen_Value_Proposition': 'Without more information about imodules.com, it is difficult to create a tailored value proposition. However, Canteen could offer a consultation to assess their breakroom needs and propose solutions for coffee, vending, and micro-market services that enhance employee satisfaction and productivity.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'There is no mention of coffee service in the scraped text.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'There is no mention of vending machine service in the scraped text.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'There is no mention of a micro market service in the scraped text.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Example Business', 'Business_Location': '123 Main Street, Anytown, CA', 'Business_Summary': 'Example Business is located in Anytown, CA.', 'Canteen_Value_Proposition': 'Canteen can provide a comprehensive refreshment solution to Example Business, including coffee service, vending machines, and a micro market, tailored to their specific needs and preferences. By offering a variety of options, Canteen can enhance employee satisfaction and productivity.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not contain any explicit mentions of coffee makers or coffee service.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not contain any explicit mentions of vending machines.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not contain any explicit mentions of a micro market.', 'Decision_Maker_Name': 'Phil Dangerfield', 'Decision_Maker_Title': 'SVP, Operations', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Cleveland Browns', 'Business_Location': 'Cleveland, OH', 'Business_Summary': 'This is the front office directory for the Cleveland Browns, an NFL team located in Cleveland, OH. It includes names and titles for various roles from management to operations.', 'Canteen_Value_Proposition': "Canteen can offer a comprehensive refreshment solution, including coffee, vending, and micro-market services, to enhance the employee experience at the Cleveland Browns' headquarters and stadium, improving morale and productivity for both front office staff and operations teams."}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not contain any information about coffee service.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not contain any information about vending machine service.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not contain any information about micro market service.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Hickman Realty Group, INC', 'Business_Location': 'Jackson, TN', 'Business_Summary': 'Hickman Realty Group, INC is a real estate company specializing in West Tennessee real estate. They have offices in Jackson, Milan, and Humboldt.', 'Canteen_Value_Proposition': 'Since Hickman Realty Group has multiple offices throughout West Tennessee, Canteen can offer coffee, micro-market, and vending machine services to improve employee satisfaction and retention at each of their locations.'}
# Processing American Closeout Wholesale, Llc - North Plaza
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The provided text does not contain any information about coffee service. Therefore, it is undetermined.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The provided text does not contain any information about vending machine service. Therefore, it is undetermined.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The provided text does not contain any information about micro market service. Therefore, it is undetermined.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Critical Infrastructure Protection & Resilience North America', 'Business_Location': 'Baton Rouge, Louisiana', 'Business_Summary': "The Critical Infrastructure Protection & Resilience North America conference brings together stakeholders from industry, operators, agencies, and governments to collaborate on securing North America's critical infrastructure. The event includes discussions, networking opportunities, and an exhibition of technologies and solutions.", 'Canteen_Value_Proposition': 'As a conference that brings together leaders in critical infrastructure, offering refreshment services, such as coffee, vending machines, and micro-markets, would enhance the attendee experience and provide convenient access to snacks and beverages during the event.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not provide any information about coffee services at the Wilson Center.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not provide any information about vending machine services at the Wilson Center.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not provide any information about micro market services at the Wilson Center.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'The Wilson Center', 'Business_Location': 'Washington, DC', 'Business_Summary': 'The Wilson Center is a non-partisan policy forum that provides analysis and facilitates discussions on critical policy issues.', 'Canteen_Value_Proposition': "Given the Wilson Center's focus on policy analysis and bringing together experts, Canteen could offer a customized refreshment solution that enhances the collaborative environment. This could include premium coffee service to fuel discussions, a micro-market with healthy snacks and diverse options for busy professionals, and convenient vending solutions for quick breaks."}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not contain any information about coffee service for the City of North Liberty.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not contain any information about vending machine service for the City of North Liberty.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not contain any information about micro market service for the City of North Liberty.', 'Decision_Maker_Name': 'T. Mulcahey', 'Decision_Maker_Title': 'City Clerk', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'tmulcahey@northlibertyiowa.org', 'Business_Name': 'City of North Liberty', 'Business_Location': '360 N Main Street, North Liberty, IA 52317', 'Business_Summary': 'The City of North Liberty is a growing community in Iowa, offering various services and resources for residents and businesses. The city government consists of elected officials and professional staff who work to ensure North Liberty is a great place to live, work, and play.', 'Canteen_Value_Proposition': 'Canteen can provide convenient refreshment solutions such as coffee, vending machines, and micro-markets to enhance the workplace environment for city employees and visitors, contributing to employee satisfaction and productivity. Canteen can also support community events by providing vending and micro-market services.'}
# {'Has_Coffee_Service': 'True', 'Has_Coffee_Service_Explanation': "The text mentions 'exclusive beverage and coffee systems' and 'A fresh hot cup of coffee means so much more to Americans than it ever did, and we have many solutions to fit your needs,' indicating that the business provides coffee services.", 'Has_Vending_Machine_Service': 'True', 'Has_Vending_Machine_Service_Explanation': "The text explicitly states 'state-of-the-art vending' and 'For nearly 60 years, AVI has been the industry standard and trend setter in vending services,' confirming the presence of vending machine services.", 'Has_Micro_Market_Service': 'True', 'Has_Micro_Market_Service_Explanation': "The text mentions 'innovative micro markets' and 'Market C is an innovative high-tech self-service convenience store,' indicating that the business has in-house micro markets.", 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'AVI Foodsystems', 'Business_Location': 'Ashburn, Virginia', 'Business_Summary': 'AVI Foodsystems is a large, independently owned food service company founded in 1960. They offer comprehensive food services, including cafes, restaurants, resident dining, micro markets, vending, catering, and beverage/coffee systems. They serve various sectors, including business and industry, education, healthcare, and leisure and entertainment.', 'Canteen_Value_Proposition': 'AVI Foodsystems is already providing coffee, vending, and micro-market services; Canteen can differentiate by offering a more customizable experience through advanced technology and data analytics, optimizing product selection, and enhancing the user experience, ultimately driving increased employee satisfaction and productivity.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The provided text does not contain any information about coffee service.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The provided text does not contain any information about vending machine service.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The provided text does not contain any information about micro market service.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'U.S. Bancorp Tower and Plaza', 'Business_Location': 'Unavailable in provided text', 'Business_Summary': "The provided text indicates an 'Access Denied' error when trying to access information about U.S. Bancorp Tower and Plaza on JLL's website. Therefore, no business details are available.", 'Canteen_Value_Proposition': 'Due to lack of information about the business, a tailored value proposition cannot be created.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not contain any information about coffee makers or coffee service at Oaks on North Plaza.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not contain any information about vending machines at Oaks on North Plaza.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not contain any information about a micro market at Oaks on North Plaza.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Oaks on North Plaza', 'Business_Location': '9125 North Plaza, Austin, TX 78753', 'Business_Summary': 'Oaks on North Plaza is a multifamily property located in Austin, Texas, featuring 62 apartment units. Yardi Matrix provides detailed data on the property, including ownership information, unit mix, rental rates, sales history, and occupancy rates.', 'Canteen_Value_Proposition': 'Canteen can offer a comprehensive refreshment solution to Oaks on North Plaza residents, potentially increasing resident satisfaction and property value. This could include coffee service for common areas, vending machines with snacks and beverages, or even a micro-market for a wider selection of food and beverage options. Focusing on convenience and enhancing the living experience could be a strong selling point.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not provide any information about coffee service.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not provide any information about vending machine service.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not provide any information about micro market service.', 'Decision_Maker_Name': 'Scott Ballard', 'Decision_Maker_Title': 'Chief People Officer MaineHealth', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'MaineHealth', 'Business_Location': '110 Free Street | Portland, ME 04101', 'Business_Summary': 'MaineHealth is a healthcare provider with multiple locations, offering a range of medical services. The headquarters is located in Portland, ME.', 'Canteen_Value_Proposition': 'Canteen can offer MaineHealth a comprehensive refreshment solution that includes coffee, vending machines, and micro-markets. This would improve employee satisfaction and productivity by providing convenient access to a variety of food and beverage options. Canteen can also help MaineHealth promote a healthy lifestyle by offering nutritious snacks and drinks.'}
# {'Has_Coffee_Service': 'True', 'Has_Coffee_Service_Explanation': "The scraped text includes the phrases 'Brewed-to-Order Coffee' and 'Coffee, Pantries & Perks', indicating that the business offers coffee services.", 'Has_Vending_Machine_Service': 'True', 'Has_Vending_Machine_Service_Explanation': "The scraped text includes the phrases 'Vending Solutions for Any Environment' and 'MARKETS & VENDING', indicating that the business offers vending machine services.", 'Has_Micro_Market_Service': 'True', 'Has_Micro_Market_Service_Explanation': "The scraped text includes the phrases '24/7 Micro-Markets Where You Need Them' and 'MARKETS & VENDING', indicating that the business offers micro market services.", 'Decision_Maker_Name': 'GLORIA K.', 'Decision_Maker_Title': 'Director of New Business', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'LetsConnect@ContinentalServes.com', 'Business_Name': 'Continental Services', 'Business_Location': '700 Stephenson Hwy, Troy, MI 48083', 'Business_Summary': 'Continental Services is a food and beverage provider for workplaces in the Great Lakes region. They offer customized dining and refreshment programs, including coffee, pantries, vending, micro-markets, and on-site dining.', 'Canteen_Value_Proposition': "Continental Services values employee satisfaction and a productive workplace. By offering coffee, micro-markets, and vending machines, the company can meet any company's needs and create an environment where employees are energized."}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not provide any explicit information about the presence of coffee makers or coffee service.', 'Has_Vending_Machine_Service': 'True', 'Has_Vending_Machine_Service_Explanation': 'The company Nayax provides solutions for the unattended machine industry.', 'Has_Micro_Market_Service': 'True', 'Has_Micro_Market_Service_Explanation': 'The text mentions "Micro Market" as one of the industries the company serves.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Nayax', 'Business_Location': 'Executive Plaza 1, 11350 Mccormick Road, Hunt Valley, Maryland 21031', 'Business_Summary': 'Nayax is a global provider of EMV certified cashless payment solutions, telemetry systems, and a management & monitoring business suite for the unattended machine industry. They are located in Hunt Valley, Maryland.', 'Canteen_Value_Proposition': "Canteen can partner with Nayax to provide integrated payment and micro-market solutions, enhancing the unattended retail experience for Nayax's clients by offering a wider range of food and beverage options, advanced inventory management, and consumer engagement programs."}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not provide any information about coffee services.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not provide any information about vending machine services.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not provide any information about micro market services.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'dineoncampus.com', 'Business_Location': 'undetermined', 'Business_Summary': 'The scraped text indicates an error message from dineoncampus.com, stating that access is blocked due to security reasons. There is no business information available from the text.', 'Canteen_Value_Proposition': "Due to the lack of information about the business and its needs, a tailored value proposition cannot be formulated. Further information about the company's size, employee needs, and current refreshment solutions is required."}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not contain information about coffee service. Thus, it is undetermined.', 'Has_Vending_Machine_Service': 'False', 'Has_Vending_Machine_Service_Explanation': 'The text focuses on Micromart Smart Stores as an alternative to traditional vending machines, highlighting benefits like increased sales and reduced costs compared to vending machines, indicating that the Micromart system is not a vending machine service.', 'Has_Micro_Market_Service': 'True', 'Has_Micro_Market_Service_Explanation': 'The scraped text extensively promotes Micromart™ Smart Stores, which are in-house micro markets that offer various products such as fresh meals, snacks, frozen goods, and electronics.', 'Decision_Maker_Name': 'Luke Kennedy', 'Decision_Maker_Title': 'Director of Culinary Operations', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'KitchenMate', 'Business_Location': 'Toronto', 'Business_Summary': 'KitchenMate operates 85 public and semi-public food service locations using Micromart technology.', 'Canteen_Value_Proposition': 'Canteen can offer Micromart solutions to KitchenMate to enhance their existing micro-market technology, potentially offering advanced AI-powered product recognition, improved inventory management, and a broader selection of products.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not contain any information about coffee makers or coffee service at the Wilson Center.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not contain any information about vending machines at the Wilson Center.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not contain any information about micro markets at the Wilson Center.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'The Wilson Center', 'Business_Location': 'Washington, DC', 'Business_Summary': 'The Wilson Center is a non-partisan policy forum that tackles global issues through independent research and open dialogue to inform actionable ideas for policymakers and public officials.', 'Canteen_Value_Proposition': "Canteen can offer The Wilson Center a tailored refreshment program to enhance employee and visitor experience, providing a variety of options such as coffee, snacks, and beverages. This can contribute to a more productive and engaging environment for the organization's scholars, staff, and guests."}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': "The provided text doesn't explicitly mention coffee service or coffee makers for employees, so it is undetermined.", 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': "The provided text doesn't explicitly mention vending machine service for employees, so it is undetermined.", 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': "The provided text doesn't explicitly mention micro market service for employees, so it is undetermined.", 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'CAVA', 'Business_Location': 'Butler Plaza, North Central Florida', 'Business_Summary': 'CAVA is a Mediterranean fast-casual restaurant chain focused on providing healthy and customizable meals. This specific job posting is for an Area Leader in North Central Florida, indicating a regional management role within the company.', 'Canteen_Value_Proposition': "As CAVA expands in North Central Florida, Canteen can provide value to CAVA by offering a customized beverage and snack program that helps attract and retain employees. Canteen's comprehensive offerings can provide additional convenience to employees, boosting morale and productivity."}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not provide any information about the presence of coffee makers at the business.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not provide any information about the presence of vending machines at the business.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not provide any information about the presence of an in-house micro market at the business.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'City of North Liberty', 'Business_Location': '360 N. Main St., North Liberty, Iowa', 'Business_Summary': "The City of North Liberty is a local government entity in Iowa, focusing on providing services and resources to its residents and businesses. It's located in the Iowa City-Cedar Rapids region and offers various amenities and community programs.", 'Canteen_Value_Proposition': "Canteen can offer a comprehensive refreshment solution tailored to the City of North Liberty's staff and visitors, potentially including coffee service for employees, vending machines in public spaces, or a micro-market in a municipal building to enhance convenience and satisfaction."}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not provide any explicit information about the presence of coffee makers or coffee service at the North Houston Association.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not provide any explicit information about the presence of vending machines at the North Houston Association.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not provide any explicit information about the presence of micro markets at the North Houston Association.', 'Decision_Maker_Name': 'Marlisa Briggs', 'Decision_Maker_Title': 'Association President', 'Decision_Maker_Phone': '(281) 875- 0660', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'North Houston Association', 'Business_Location': '21021 Spring Brook Plaza Dr. Suite #175, Spring, TX 77379', 'Business_Summary': 'The North Houston Association (NHA) is a regional business association comprised of nearly 150 companies. It focuses on addressing regional issues related to mobility, the environment, and development trends in north Harris and Montgomery County. NHA provides networking opportunities, educational forums, and advocates for projects and policies that support a positive business climate and improve the quality of life in the region.', 'Canteen_Value_Proposition': "Canteen can offer a tailored refreshment solution to the North Houston Association and its member companies. By providing coffee, vending, or micro-market services, Canteen can enhance the workplace environment for NHA members and employees, supporting productivity and satisfaction during meetings, events, and daily operations. This aligns with NHA's goal of improving the quality of life and fostering a positive business climate within the region."}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not mention any coffee service. Therefore, it is undetermined whether the business has coffee makers or not.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not mention any vending machine service. Therefore, it is undetermined whether the business has vending machines or not.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not mention any micro market service. Therefore, it is undetermined whether the business has an in-house micro market or not.', 'Decision_Maker_Name': 'Robin Marlow', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': '763-535-6794', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'North Park Plaza', 'Business_Location': '8201 45th Avenue N, New Hope, MN 55428', 'Business_Summary': 'North Park Plaza is a 105-unit housing site providing permanent supportive housing for low-income older adults, located in New Hope, MN. It offers amenities such as common areas, a solarium, an outdoor patio, and a dining room. The building is managed by Volunteers of America.', 'Canteen_Value_Proposition': 'Canteen can provide coffee, vending, and micro-market services to enhance the amenities offered at North Park Plaza. By offering these services, Canteen can improve the quality of life for residents and staff, creating a more comfortable and convenient living environment. Canteen could emphasize the convenience and accessibility of fresh food, snacks, and beverages for the residents, especially considering the location is close to shopping and public transport. Additionally, Canteen can tailor its offerings to cater to the specific dietary needs and preferences of older adults.'}
# ...
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not provide any explicit information about coffee makers. Therefore, it is undetermined whether the business has coffee service.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not provide any explicit information about vending machines. Therefore, it is undetermined whether the business has vending machines.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not provide any explicit information about micro markets. Therefore, it is undetermined whether the business has a micro market.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'CEDARst Companies', 'Business_Location': '151 W Huron St, Chicago, IL 60654', 'Business_Summary': 'CEDARst Companies is a fully integrated real estate company that delivers best-in-class services across development, construction, management, and hospitality. They are a nationally recognized multi-family developer with offices across the country.', 'Canteen_Value_Proposition': "Canteen can provide convenience and refreshment solutions for CEDARst's properties, enhancing the living experience for residents in their multi-family developments. This includes offering coffee, vending machines, and micro-markets tailored to the needs of the residents and staff, adding value to the properties and creating a more community-oriented living environment."}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not provide any information about coffee services at the business.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not provide any information about vending machine services at the business.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not provide any information about micro market services at the business.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Bridge Investment Group Holdings LLC', 'Business_Location': 'Not specified in the text, but operates across multiple locations.', 'Business_Summary': 'Bridge Investment Group is a leading alternative investment manager committed to driving value across its verticals. They invest in real estate-backed credit, industrial net-leased real estate, multifamily units, single-family rentals, and logistics spaces. They have $50B assets under management and 2,200 employees.', 'Canteen_Value_Proposition': "Canteen can provide a tailored refreshment program that enhances the workplace experience for Bridge Investment Group's 2,200 employees. A micro-market or a modernized vending program can be installed in their offices and managed properties, providing convenient access to snacks, meals, and beverages, improving employee satisfaction and productivity."}
# Processing Social Security Administration - Jackson Social Security Office
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not provide any information regarding coffee service at the business.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not provide any information regarding vending machine service at the business.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not provide any information regarding micro market service at the business.', 'Decision_Maker_Name': 'Dr. Gloria Anderson', 'Decision_Maker_Title': 'Executive Director', 'Decision_Maker_Phone': '405-242-5319', 'Decision_Maker_Email_Address': 'wkjla@wkjackson.org', 'Business_Name': 'W.K. Jackson Leadership Academy', 'Business_Location': '5700 N Kelley, Suite A Oklahoma City, OK 73111', 'Business_Summary': 'W.K. Jackson Leadership Academy is an elementary school located in Oklahoma City, OK. The academy also offers afterschool childcare.', 'Canteen_Value_Proposition': 'Canteen can provide a customized coffee, vending, and micro-market solution for W.K. Jackson Leadership Academy to enhance the staff and visitor experience, creating a more appealing and convenient environment.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not provide any information about coffee services.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not provide any information about vending machine services.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not provide any information about micro market services.', 'Decision_Maker_Name': 'Amy L. Peck', 'Decision_Maker_Title': 'Principal', 'Decision_Maker_Phone': '402-391-1991', 'Decision_Maker_Email_Address': 'Email', 'Business_Name': 'Jackson Lewis', 'Business_Location': 'Omaha, White Plains', 'Business_Summary': 'Jackson Lewis is a law firm focusing on workplace law. They offer services such as immigration counsel, compliance assistance, and litigation support.', 'Canteen_Value_Proposition': "As a law firm with multiple locations, Jackson Lewis can benefit from Canteen's services by providing convenient and accessible refreshments for their employees. This can improve employee satisfaction and productivity, especially during long hours and demanding cases. Canteen can offer a tailored solution with coffee, vending, and micro-market options to suit the needs of each location."}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not provide any information about the presence of coffee makers or a coffee service at the business.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not provide any information about the presence of vending machines at the business.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not provide any information about the presence of an in-house micro market at the business.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Jackson National Life Insurance Company', 'Business_Location': '1 Corporate Way, Lansing, MI 48951', 'Business_Summary': 'Jackson Financial Inc. is the parent company of Jackson National Life Insurance Company and Jackson National Life Insurance Company of New York. They offer annuities and retirement planning resources. The company is located in Lansing, Michigan.', 'Canteen_Value_Proposition': 'Since Jackson focuses on employee well-being and has over 3,800 U.S. associates, Canteen can offer a customized refreshment program with coffee, vending, and micro-market options to enhance the workplace experience and support employee satisfaction.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': "The provided text does not contain any information about the company's coffee service.", 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': "The provided text does not contain any information about the company's vending machine service.", 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': "The provided text does not contain any information about the company's micro market service.", 'Decision_Maker_Name': 'Andrew F. Maunz', 'Decision_Maker_Title': 'Of Counsel', 'Decision_Maker_Phone': '412-338-5144', 'Decision_Maker_Email_Address': 'Andrew.Maunz@jacksonlewis.com', 'Business_Name': 'Jackson Lewis P.C.', 'Business_Location': 'Pittsburgh, Pennsylvania', 'Business_Summary': 'Jackson Lewis P.C. is a law firm with an office in Pittsburgh, Pennsylvania. Andrew F. Maunz is of counsel in the Pittsburgh office.', 'Canteen_Value_Proposition': "As a law firm, Jackson Lewis may benefit from providing convenient and high-quality refreshment options for its employees and clients. Canteen can offer a range of coffee, micro-market, and vending solutions to enhance the workplace experience, improve employee satisfaction, and create a welcoming environment for visitors. Given Andrew Maunz's focus on employment law, a well-equipped breakroom could be seen as an investment in employee well-being and productivity."}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'There is no mention of coffee service in the scraped text. Therefore, it is undetermined whether the business has coffee makers.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'There is no mention of vending machine service in the scraped text. Therefore, it is undetermined whether the business has vending machines.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'There is no mention of a micro market service in the scraped text. Therefore, it is undetermined whether the business has a micro market.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Example Business', 'Business_Location': 'Example Location', 'Business_Summary': 'This is an example business located in an example location. Further details about the business are needed.', 'Canteen_Value_Proposition': 'To provide a comprehensive refreshment solution, including coffee, vending, and micro-market options, tailored to enhance employee satisfaction and productivity, pending further information about current solutions.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The article discusses staffing and budget issues at the Social Security Administration. There is no mention of coffee service.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The article discusses staffing and budget issues at the Social Security Administration. There is no mention of vending machine service.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The article discusses staffing and budget issues at the Social Security Administration. There is no mention of micro market service.', 'Decision_Maker_Name': 'Kilolo Kijakazi', 'Decision_Maker_Title': 'acting Commissioner', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Social Security Administration', 'Business_Location': 'Woodlawn, Maryland', 'Business_Summary': 'The Social Security Administration (SSA) is a US government agency that administers social security. The article discusses staffing and budget issues at the Social Security Administration headquarters in Woodlawn, Maryland.', 'Canteen_Value_Proposition': 'Canteen can offer solutions to improve employee satisfaction and productivity by providing convenient and accessible refreshment options, such as coffee, vending machines, or a micro-market, to help alleviate some of the stress caused by understaffing and heavy workloads.'}
# {'Has_Coffee_Service': 'undetermined', 'Has_Coffee_Service_Explanation': 'The scraped text does not contain any information about coffee service.', 'Has_Vending_Machine_Service': 'undetermined', 'Has_Vending_Machine_Service_Explanation': 'The scraped text does not contain any information about vending machine service.', 'Has_Micro_Market_Service': 'undetermined', 'Has_Micro_Market_Service_Explanation': 'The scraped text does not contain any information about micro market service.', 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Jackson Lewis P.C.', 'Business_Location': 'Major cities nationwide', 'Business_Summary': 'Jackson Lewis P.C. is a law firm focused on employment and labor law since 1958, with 1,000+ attorneys located in major cities nationwide. They help employers develop proactive strategies, strong policies, and business-oriented solutions to cultivate high-functioning workforces.', 'Canteen_Value_Proposition': 'As a law firm with over 1,000 employees, Jackson Lewis P.C. could benefit from providing convenient refreshment options for their employees. Canteen can offer a customized coffee, micro-market, and vending machine solution that caters to the specific needs and preferences of their workforce, enhancing employee satisfaction and productivity.'}
# {'Has_Coffee_Service': 'True', 'Has_Coffee_Service_Explanation': "The scraped text includes a section titled 'Office coffee' and mentions 'efficient coffee brewers' to 'increase energy levels and morale throughout the work day'.", 'Has_Vending_Machine_Service': 'True', 'Has_Vending_Machine_Service_Explanation': "The scraped text explicitly mentions 'State of the art vending machines serving you traditional and healthy snacks, beverages, and fresh food with modern technology'.", 'Has_Micro_Market_Service': 'True', 'Has_Micro_Market_Service_Explanation': "The scraped text promotes micro-markets as 'An unattended convenience store offering a wide variety of fresh food, snacks, and beverages right in your Jackson break room'.", 'Decision_Maker_Name': 'undetermined', 'Decision_Maker_Title': 'undetermined', 'Decision_Maker_Phone': 'undetermined', 'Decision_Maker_Email_Address': 'undetermined', 'Business_Name': 'Graham Snack Foods', 'Business_Location': '53 Lawrence Switch Road, Jackson, TN 38301', 'Business_Summary': 'Graham Snack Foods is a family-owned and operated business serving West Tennessee since 1937. They offer micro-markets, vending machines, and office coffee services to businesses in the Jackson area. They pride themselves on being 100% cashless and connected, utilizing wireless technology and cashless payments.', 'Canteen_Value_Proposition': 'Canteen can provide Graham Snack Foods with innovative and modern vending solutions, micro-market designs, and office coffee service options. Canteen can also help them expand their service offerings and improve their technology infrastructure with cashless payment systems and remotely monitored inventory.'}

# %%
#!/usr/bin/env python3
import argparse
from pathlib import Path

import pandas as pd

def concat_csvs(folder: str) -> pd.DataFrame:
    """
    Read every .csv in `folder`, drop html_content/html_content_cleaned if they exist,
    and return a single concatenated DataFrame.
    """
    folder = Path(folder)
    dfs = []
    for csv_path in folder.glob("*.csv"):
        df = pd.read_csv(csv_path)
        # drop unwanted columns silently if they don't exist
        df = df.drop(columns=["html_content", "html_content_cleaned"], errors="ignore")
        dfs.append(df)

    if not dfs:
        return pd.DataFrame()  # empty if no CSVs found
    return pd.concat(dfs, ignore_index=True)

concat_dfs = concat_csvs('intermediate-outputs')

concat_dfs.to_csv("output/concatenated_05092025.csv", index=False)

# %%
# concatenated_df = pd.read_csv("output/concatenated_05092025.csv")

# %%
# concatenated_df[concatenated_df['file_name'].str.contains("Bridge")]

# %%
parent_child_df.to_csv("output/parent_child.csv", index=False)

# %% [markdown]
# # Archive

# %%
def orchestrate_sitemap_parse(sitemap_df: pd.DataFrame) -> pd.DataFrame:
    """ 
        Orchestrate the parsing of a sitemap DataFrame and return the updated DataFrame.
        Args:
            sitemap_df: pd.DataFrame, DataFrame containing the sitemap data.
        Returns:    
            pd.DataFrame: Updated DataFrame with parsed data.
    """
    # Iterate over sites in the sitemap
    for idx in range(len(sitemap_df)):

        # Get the account name, address, and city from the sitemap
        account_name = sitemap_df.iloc[idx]['Account Name']
        address = sitemap_df.iloc[idx]['Address']
        city = sitemap_df.iloc[idx]['City']

        # Download HTML files from GCS and convert to DataFrame
        df = download_html_files_to_dataframe(
            "data-extraction-services",
            f"Canteen-Sales_Poc/results/{account_name} - {address} - {city}"
        )
        # Clean the HTML content
        df['html_content_cleaned'] = df['html_content'].apply(lambda x: extract_text_from_html(str(x)))

        # Perform LLM evaluation
        df = parallel_llm_evals(df)

        # Aggregate the results via LLM and write back to the dataframe
        sitemap_df = aggregator(sitemap_df, df, idx)

    return sitemap_df

sitemap_df = orchestrate_sitemap_parse(sitemap_df)

# local folder version
# df = html_folder_to_dataframe("./input/test/")

# %%
sitemap_df.to_csv("sitemap_test.csv")

# %% [markdown]
# # Other Approaches

# %%
import requests
from typing import Optional

def fetch_html(url: str, timeout: float = 10.0) -> str:
    """
    Retrieve the raw HTML content of a web page.

    Parameters
    ----------
    url : str
        The full URL of the page to fetch (e.g., "https://www.utilicor.ca/our-team/").
    timeout : float, optional
        How many seconds to wait for the server to send data before giving up.

    Returns
    -------
    str
        The HTML source of the page.

    Raises
    ------
    requests.exceptions.RequestException
        For network-related errors (connection issues, timeouts, DNS errors, etc.).
    ValueError
        If the server responds with a non-2xx HTTP status code.
    """
    try:
        response = requests.get(url, timeout=timeout)
        # Raise for HTTP errors (4xx/5xx)
        response.raise_for_status()
        return response.text
    except requests.exceptions.HTTPError as http_err:
        raise ValueError(f"Failed to fetch {url}: HTTP {response.status_code}") from http_err
    # Let other RequestExceptions bubble up

# %%
sitemap_df.to_csv("sitemap_test.csv", index=False)

# %%
fetch_html("https://www.jmcss.org")
# Out:
# ''

# %% [markdown]
# # School Example

# %%
# account_name = sitemap_df.iloc[idx]['Account Name']
# address = sitemap_df.iloc[idx]['Address']
# city = sitemap_df.iloc[idx]['City']


schools_df = html_folder_to_dataframe("./input/schools/")

schools_df['html_content_cleaned'] = schools_df['html_content'].apply(lambda x: extract_text_from_html(str(x)))

# schools_df = parallel_llm_evals(schools_df)

# sitemap_df = aggregator(sitemap_df, schools_df, idx)

# %%
schools_df['html_content_cleaned'].values[0]
# Out:
# 'Jackson-Madison County School System logo\nJackson-Madison County\nSchool System\nJMCSS Directory\nBoard of Education\nDepartments\nOffice of the Superintendent\nSchools\nJMCSS Schools\nAlexander Elementary\nAndrew Jackson\nArlington Elementary\nCommunity Montessori\nDenmark Elementary\nEast Elementary\nIsaac Lane Elementary\nJackson Academic STEAM Academy\nJackson Careers and Technology School\nJackson Central-Merry High School\nJackson Central-Merry Middle School\nJCM Early College High\nLiberty Technology High School\nLincoln Elementary\nMadison Academic High School\nNorth Parkway Middle School\nNorth Side High School\nNortheast Middle School\nNova Early Learning Center\nParkview Prep Academy\nPope Elementary\nRose Hill School\nSouth Elementary School\nSouth Side High School\nThelma Barker Elementary School\nWest Bemis Middle School\nMenus\nTransportation\nweCARE\nStudents\nParents\nEmployee Portal\nCommunications Department\nJoin Our Team!\nBest By Any Measure\nJackson-Madison County School System\n310 North ParkwayJackson, TN 38305\nContact Us\nP 731-664-2500\nF 731-664-2502'

# %%
import textwrap

# %%
print(textwrap.fill(extract_text_from_html(html),100))
# Out:
# About Utilibond See the Process Parts Catalogue Home About Us About Utilicor Our Team Contact Us
# Testimonials Keyhole Technology What is Keyhole Technology? The Keyhole Process Benefits of Keyhole
# Keyhole Application Coring Equipment Coring Equipment Overview UTC1870 Self-Propelled Coring Unit
# Series 500 Heavy Duty Coring Truck MD 300 Coring Truck MPX-SS Coring Unit Minicor-3 Coring
# Attachment MC-450 Coring Attachment MTC100 – Discontinued Parts Coring Drums & Center Bits Parts and
# Tools Accessories Core Drum Re-Tipping Cold Weather Reinstatement System Diamond Core Bits Utilibond
# What is Utilibond The Solution for Utility Cuts Utilibond Testing Utilibond Data Utilibond Additives
# Reinstatement Process with Utilibond Approvals Municipal Keyhole Approvals Core Bond Testing Reports
# & White Papers Resources Articles Videos Coring Tips Carbon Footprint Picture Gallery Banners and
# Swag Product Bulletins FAQS Where to Buy Product Info Our Team Home Our Team The Utilicor Team is
# comprised of a group of diversely talented individuals all committed to delivering the highest
# quality coring equipment, products and services. We strive day in and day out to exceed your
# company’s expectations. We understand that we are not your only choice when choosing a keyhole
# equipment and materials supplier, but we endeavour to be your first choice. Andrew Pollock President
# and CEO Andrew Pollock is a business executive whose well-honed customer-service approach allows the
# company to effectively understand and address all of the product-oriented requirements of our
# customers. Andrew co-founded Utilicor in 2012 and has worked in every aspect of the business over
# the past 18 years. As President and CEO Andrew guides the company in achieving its mission of
# delivering high-quality, cost-effective products and services to the North American utility
# maintenance and service marketplace. He also functions as General Manager and is responsible for the
# on-time production and quality assurance of manufacturing operations. His focus is on product
# development and improvement programs that will increase the value-added performance of the company’s
# industry leading coring units and permanent pavement bonding compound, Utilibond™. Bogdan Lupu CPA
# CGA, Controller Bogdan Lupu joined Utilicor with 8 years of well-honed financial and business
# administration skills from the technology sector having worked in both large multinationals such as
# General Electric and IBM as well as Toronto-based start-ups, where he managed the accounting and
# finance departments. With working experience in Canada, France and Hungary and with working
# proficiency in English, Spanish, French and Romanian, Bogdan brings a multinational, cross-cultural
# perspective to the company. Blended with his experience in the technology sector and his proficiency
# in multiple accounting software packages, Bogdan is focused on implementing process improvements to
# increase efficiency and enable the Company to scale up to meet the future needs of our expanding
# family of customers worldwide. Pat Colangelo Production Manager Pat Colangelo has more than 25 years
# of experience in a variety of manufacturing, fabrication and assembly operations, including several
# years of direct experience with the Utilicor product line as Plant Superintendent of the ISO 9001
# 2000 certified manufacturing facility that supplied Utilicor with many of the fabricated parts and
# components used in its coring units, before those activities were brought in-house.Technically
# trained as a Machine Operator and Precision Metal Fabricator, Pat began his career as a sheet metal
# mechanic with one of North America’s leading manufacturers and suppliers of parts and components for
# the transportation, construction equipment and heavy machinery industries, and rose through the
# ranks to become Production Supervisor responsible for production, fabrication and scheduling.In
# 2008, Pat joined Utilicor Technologies as Production Manager and is responsible for all aspects of
# sourcing, scheduling, production and quality assurance. His strong commitment to customer service
# and fast, accurate and high quality work, will help Utilicor maintain its technological leadership
# in the global market for truck, trailer and skid steer-mounted coring equipment and its reputation
# for meeting the specialized demands of its customers with innovative solutions that keeps it at the
# cutting edge of keyhole technology. Jeff Haas Manager Engineering Services Jeff Haas is a Mechanical
# Engineering Design Technologist with more than 30 years’ experience in a wide variety of
# manufacturing environments that includes design and hands-on manufacture from prototypes to finished
# product. This knowledge extends to encyclopedic operational familiarity with  a wide range of
# manufacturing and production equipment that includes  laser and plasma profiling, boring mills, CNC
# and manual lathes, welding, iron working, shears and punch, brake and drill presses. By combining
# “out of the box” design thinking and problem solving with well-honed computer skills that include
# advanced levels of AutoCad, Solidworks,  Visual Manufacturing, QuickBooks and other ERP software,
# Jeff brings together an arsenal of design, manufacturing and business assets to arrive at the most
# practical and cost-effective solution that will help Utilicor maintain its technological leadership
# in the global market for truck, trailer, skid steer-mounted and self-propelled coring equipment. And
# unlike many designers Jeff can, and often does, follow his designs into production and manufacture
# with a full set of production scheduling,  urchasing and quality assurance skills to ensure that
# those designs meet all of the requirements and expectations of the customer and the  manufacturer.
# Combined with a “can-do” attitude, these skills and experience, and years  of customer contact for
# sales issues, order entry, quotations and product specification will help the Company ensure that
# industry and customer requirements are met by engineering specifications and manufacturing quality
# that enhance its reputation for meeting the specialized demands of its customers with innovative
# solutions that keeps it at the cutting edge of keyhole technology. Jody Robles Manager Field
# Operations Jody Robles joined Utilicor Technologies in 2018 from Southwest Gas a local gas
# distribution company with operations in Arizona, Nevada and California, where during 17-years of
# service he rose to become the resident expert on keyhole coring and reinstatement technology and
# established it, along with vacuum excavation, as the approved and preferred method of performing and
# repairing pavement utility cuts throughout the company’s service area. Jody is proficient in all
# aspects of gas service operations making use of the keyhole coring process including: cathodic
# protection, distribution pipe and service replacement using HDD and Split & Pull, and the connection
# and abandonment of services on moratorium roadways. As Manager of Field Operations, Jody is also
# responsible for trouble shooting, problem solving and process training with contractors, local
# municipalities, transportation and other agencies and utilities. As our “agent of change”, Jody is
# our “how-to-guy” in the field, and our eyes and ears to issues that will help maintain our
# technological and performance leadership and keep Utilicor at the “cutting edge of keyhole
# technology.” Michael Knowles Customer Relations Manager Michael brings 30 years of customer
# relations experience and well honed sales, coaching and project management skills to Utilicor. He
# has worked with companies such as Xerox, Unitel Communications and Eagle’s Flight Creative Training
# Excellence. Michael facilitates our sales process by coordinating internal and external efforts to
# ensure that they meet the needs of our customer. Recognizing that good communications are essential
# to successful outcomes, Michael contributes to smooth execution in all areas to help us achieve the
# most positive experience possible for each and every one of our customers. Nikolaus Taylor Manager
# Business Development Nik Taylor is starting his 8th year in the underground construction industry as
# Utilicor Technologies Inc. Manager of Business Development. Nik started his career in underground
# construction with HammerHead Trenchless and Subsite Electronics. His professional career began as an
# Art Director at a Newspaper in San Diego County and worked in marketing and project management in
# electrical sign construction before joining the underground construction industry. Nik currently
# serves as the Treasurer of the Board for the NASTT South Central Chapter. Nik has worked with the
# Ditch Witch dealer channel, assisted damage prevention associations, and has helped develop training
# and best practices for large organizations. Ryan Singh Hydraulics and Electrical Subject Matter
# Expert Ryan Singh has been with Utilicor for over a decade and has had a hand in designing, wiring
# and plumbing every Utilicor unit on the market. Overseeing the Utilicor hydraulics team, his decades
# of technical hydraulics experience make him our premier resource when customers need to troubleshoot
# Utilicor units. Get in Touch 49 Sheffield Street Toronto, Ontario, Canada M6M 3E5 888-572-6666,
# 416-391-3901 info@utilicor.ca Services About Approvals Keyhole Technology Resources Discover
# Products Applications Parts service Newsroom © Utilicor Technologies. All rights reserved. Design By
# - Techkriti Group Terms of Use Privacy Policy WhatsApp us
